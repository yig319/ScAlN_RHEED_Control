# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib import cm
import sys
sys.path.append('../py-characterization/src/XRD/')
from xrd_functions import plot_rsm

# %% [markdown]
# ### example for best visualization of RSMs

# %%
files = glob.glob('../data/RSM YY128/*RSM*.xrdml')[1:]
files
# Out:
# ['../data/RSM YY128\\RSM 3degree_-1-35 peak for cubic_number2.xrdml',
#  '../data/RSM YY128\\YY128_NSO_240_RSM slow2.xrdml',
#  '../data/RSM YY128\\YY128_NSO_33-2_RSM slow.xrdml',
#  '../data/RSM YY128\\YY128_NSO_332_RSM 1.xrdml',
#  '../data/RSM YY128\\YY128_NSO_420_RSM SLOW.xrdml']

# %%
file = files[1]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]
# plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(4,6),
#          xlim=(1.52, 1.613), ylim=(4.6, 4.78), 
#          log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=5, vmax=None, save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_full')

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.52, 1.611), ylim=(4.6, 4.78), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=3000, custom_bg_color=None,
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_3_3000')

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.52, 1.611), ylim=(4.6, 4.78), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=3000, custom_bg_color='white',
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_3_3000_white_bg')

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.52, 1.611), ylim=(4.6, 4.78), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=8, vmax=3000, custom_bg_color='white',
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_8_3000_white_bg')

# %% [markdown]
# ### generate figures

# %%
files = glob.glob('../data/YY189_RSM_240 332 420/*RSM*.xrdml')
files
# Out:
# ['../data/YY189_RSM_240 332 420\\YY189_RSM 240 slow.xrdml',
#  '../data/YY189_RSM_240 332 420\\YY189_RSM 332 slow.xrdml',
#  '../data/YY189_RSM_240 332 420\\YY189_RSM 420 slow.xrdml']

# %%
file = files[0]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.518, 1.613), ylim=(4.63, 4.782), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=2000, custom_bg_color=None,
         save_path=f'../data/YY189_RSM_240 332 420/RSM_Plot/{filename}_viridis_3_2000')

# %%
file = files[1]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.521, 1.613), ylim=(4.59, 4.792), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=3000, custom_bg_color=None,
         save_path=f'../data/YY189_RSM_240 332 420/RSM_Plot/{filename}_viridis_3_3000')

# %%
file = files[2]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.52, 1.60), ylim=(4.595, 4.78), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=700, custom_bg_color=None,
         save_path=f'../data/YY189_RSM_240 332 420/RSM_Plot/{filename}_viridis_3_700')

# %%
files = glob.glob('../data/RSM YY128/*RSM*.xrdml')[1:]
files
# Out:
# ['../data/RSM YY128\\RSM 3degree_-1-35 peak for cubic_number2.xrdml',
#  '../data/RSM YY128\\YY128_NSO_240_RSM slow2.xrdml',
#  '../data/RSM YY128\\YY128_NSO_33-2_RSM slow.xrdml',
#  '../data/RSM YY128\\YY128_NSO_332_RSM 1.xrdml',
#  '../data/RSM YY128\\YY128_NSO_420_RSM SLOW.xrdml']

# %%
file = files[0]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(-2.53, -2.425), ylim=(3.86, 4.08), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=5, vmax=200, custom_bg_color=None,
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_5_200')

# %%
file = files[1]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.52, 1.611), ylim=(4.6, 4.78), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=3000, custom_bg_color=None,
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_3_3000')

# %%
file = files[2]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.525, 1.61), ylim=(4.6, 4.80), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=3000, custom_bg_color=None,
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_3_3000')

# %%
file = files[3]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.533, 1.61), ylim=(4.578, 4.78), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=5, vmax=3000, custom_bg_color=None,
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_5_3000')

# %%
file = files[4]
filename = file.split('/')[-1].split('\\')[-1].split('.')[0]

Qx, Qz, intensity = plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, figsize=(5, 6),
         xlim=(1.515, 1.61), ylim=(4.64, 4.805), 
         log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, vmin=3, vmax=2000, custom_bg_color=None,
         save_path=f'../data/RSM YY128/RSM_Plot/{filename}_viridis_3_2000')

# %% [markdown]
# ## draft

# %%
for file in glob.glob('../data/RSM YY128/RSM_Plot/*RSM*.xrdml')[1:]:
    filename = file.split('/')[-1].split('\\')[-1].split('.')[0]
    plot_rsm(file, reciprocal_space=True, title=filename, cmap=cm.viridis, 
             log_scale=True, cbar_value_format='actual', cbar_levels=20, cbar_ticks=10, save_path=f'../data/RSM YY128/RSM_Plot/{filename}')
# Out:
# c:\Users\yig319\LU Student Dropbox\Yichen Guo\SRO_STO_Drexel_TSST\notebooks\../py-characterization/src/XRD\xrd_functions.py:70: UserWarning: Log scale: values of z <= 0 have been masked
#   cs = ax.contourf(Qx, Qz, intensity, levels=levels, cmap=cmap,
